# %%
# importing all the libs
from sklearn.linear_model import LinearRegression
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
dataset=pd.read_csv("advertising_vs_sales.csv")
dataset
# Out:
#     Advertising_Budget         Sales
# 0                15069  53780.703094
# 1                 3849  14902.104270
# 2                 8390  17297.372173
# 3                12922  26827.765170
# 4                 3489  19159.256454
# 5                10823  29347.285382
# 6                10207  10176.848813
# 7                10540  29980.696033
# 8                17364  54853.715355
# 9                 5611  22606.146588
# 10                6878  10926.421305
# 11               17347  29947.426959
# 12                1851   1367.768590
# 13               19071  80217.351261
# 14                7833   4132.510514
# 15               12938  23917.649035
# 16                3427  12487.918897
# 17                5000  11254.747524
# 18                6052  13127.951043
# 19                3738  29592.209980
# 20                6387   7434.900580
# 21                9002  22362.194523
# 22                6536  18359.074418
# 23               14479  28150.133149
# 24                4913  -2124.027388
# 25               18450  48818.176543
# 26               11636  47226.665759
# 27                6726  20860.828951
# 28                4373  11833.225870
# 29               13161  33729.804358
# 30                3082   5120.822642
# 31               17281  55037.323201
# 32               16305  35708.077262
# 33               10817  13474.645156
# 34               12261  14835.960744
# 35                1417   4332.590142
# 36                9808  35126.924632
# 37                4267  13042.352516
# 38               18209  42348.812147
# 39                6745  21446.912966
# 40               12338  32707.123439
# 41                1412  11791.904737
# 42                8543  34622.538874
# 43                8587  11923.598714
# 44                1728 -19075.965636
# 45               12657  28127.132014
# 46                6988   7276.585328
# 47               19888  58039.581866
# 48                3967   2674.162047
# 49               15527  20059.713614

# %%
linearreg= LinearRegression()

# %%
X,y = dataset[["Advertising_Budget"]],dataset["Sales"]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.33)

# %%
linearreg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
linearreg.predict([[15000009]])
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([40555315.05101594])

# %%
from sklearn.metrics import r2_score

y_pred = linearreg.predict(X_test)

print("R2 Score:", r2_score(y_test, y_pred))
# Out:
# R2 Score: 0.6051961932237566

# %%
print(y_pred)
# Out:
# [47162.90279587 13833.64908833  3928.97146942 29819.57703892
#   9115.2045224   6321.99349856 27058.8137714  45483.73140593
#  39683.69496243  5702.78214864   600.37246617  5029.49120485
#   7133.18740674 42547.20945831 30536.13165782 23194.82678876
#   -586.67461947]
